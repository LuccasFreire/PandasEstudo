# %%
import pandas as pd
venda = {'data': ['15/02/2023', '23/05/2025'],
         'valor': [500, 350],
         'qtde': [2, 50],
        }
vendas_df = pd.DataFrame(venda)

# %%
print(vendas_df)
# Out:
#          data  valor  qtde
# 0  15/02/2023    500     2
# 1  23/05/2025    350    50

# %%
display(vendas_df)
# Out:
#          data  valor  qtde
# 0  15/02/2023    500     2
# 1  23/05/2025    350    50

# %%
vendas_df = pd.read_excel("Vendas.xlsx")
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# 1               2             180          360
# 2               1             368          368
# 3               3             200          600
# 4               1              71           71
# ...           ...             ...          ...
# 93905           2             283          566
# 93906           2              79          158
# 93907           3              67          201
# 93908           5             114          570
# 93909           4             259         1036
#
# [93910 rows x 7 columns]

# %%
display(vendas_df.head(10))
print(vendas_df.shape)
display(vendas_df.describe())
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# 4            Chinelo Liso           1              71           71
# 5             Cinto Linho           1             248          248
# 6                   Calça           1             170          170
# 7           Polo Listrado           4             149          596
# 8  Camisa Gola V Listrado           1             116          116
# 9             Camisa Liso           1             105          105
# (93910, 7)
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %%
produtos = vendas_df[['Produto', 'Valor Unitário']]
display(produtos)
# Out:
#                  Produto  Valor Unitário
# 0         Sapato Estampa             358
# 1               Camiseta             180
# 2          Sapato Xadrez             368
# 3                Relógio             200
# 4           Chinelo Liso              71
# ...                  ...             ...
# 93905     Mochila Xadrez             283
# 93906  Pulseira Listrado              79
# 93907     Cueca Listrado              67
# 93908     Pulseira Linho             114
# 93909      Casaco Xadrez             259
#
# [93910 rows x 2 columns]

# %%
#PEGAR SOMENTE UMA LINHA
#display(vendas_df.loc[0:5])

#Pegar linhas por condicao
#display(vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping'])

#Pegar linhas por condicao e determinadas colunas
#display(vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping', ['Produto', 'Quantidade', 'Valor Final']])

#Pegar um item especifico linha x col
#display(vendas_df.loc[1, 'Produto'])

# %%
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
#vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
#print(vendas_df)

# %%
vendas_df.loc[:, "Imposto"] = 0
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# 0               1             358          358     17.90        0
# 1               2             180          360     18.00        0
# 2               1             368          368     18.40        0
# 3               3             200          600     30.00        0
# 4               1              71           71      3.55        0
# ...           ...             ...          ...       ...      ...
# 93905           2             283          566     28.30        0
# 93906           2              79          158      7.90        0
# 93907           3              67          201     10.05        0
# 93908           5             114          570     28.50        0
# 93909           4             259         1036     51.80        0
#
# [93910 rows x 9 columns]

# %%
#vendas_df_dez = pd.read_excel("Vendas - Dez.xlsx")
vendas_df_dez = pd.read_excel("Vendas - Dez.xlsx")
#vendas_df = vendas_df_dez.append(vendas_df_dez)
display(vendas_df)
# Out:
# C:\Users\Lucas Freire\AppData\Local\Temp\ipykernel_8740\4061359023.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_df = vendas_df_dez.append(vendas_df_dez)
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [14178 rows x 7 columns]

# %%
#EXCLUIR LINHA E COLUNA
vendas_df = vendas_df.drop('Comissão', axis = 1)
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [14178 rows x 7 columns]

# %%
#VALORES VAZIOS
#Deletar linhas e colunas completamente vazias
#vendas_df = vendas_df.dropna(how='all', axis = 1)

#Deletar linhas que possuem pelo menos 1 valor vazio
#vendas_df = vendas_df.dropna()

#Preencher valors vazios
#Preencher com a media da coluna
#vendas_df['Comissão'] = vendas_df['Comissão'].fillna(vendas_df['Comissão'].mean())

#Preencher com o ultimo valor
#vendas_df = vendas_df.ffill()

# %%
#value count
transacoes_loja = vendas_df['ID Loja'].value_counts()
display(transacoes_loja)

#groupby
faturamento_produto = vendas_df[['Produto', 'Valor Final']].groupby('Produto').sum()
display(faturamento_produto)
# Out:
# Rio Mar Recife                      732
# Iguatemi Campinas                   630
# Shopping Morumbi                    612
# Shopping Eldorado                   608
# Salvador Shopping                   604
# Palladium Shopping Curitiba         602
# Center Shopping Uberlândia          600
# Shopping Vila Velha                 598
# Rio Mar Shopping Fortaleza          588
# Parque Dom Pedro Shopping           580
# Shopping Iguatemi Fortaleza         580
# Passei das Águas Shopping           578
# Bourbon Shopping SP                 572
# Shopping Recife                     572
# Shopping União de Osasco            568
# Ribeirão Shopping                   554
# Shopping Ibirapuera                 546
# Shopping SP Market                  544
# Shopping Barra                      520
# Shopping Midway Mall                518
# Iguatemi Esplanada                  516
# Norte Shopping                      510
# Shopping Center Interlagos          508
# Novo Shopping Ribeirão Preto        478
# Shopping Center Leste Aricanduva    460
# Name: ID Loja, dtype: int64
#                   Valor Final
# Produto
# Bermuda                 36900
# Bermuda Estampa         37180
# Bermuda Linho           51090
# Bermuda Liso            37366
# Bermuda Listrado        40424
# ...                       ...
# Tênis Estampa           64000
# Tênis Linho             69972
# Tênis Liso              68096
# Tênis Listrado          51876
# Tênis Xadrez            59052
#
# [120 rows x 1 columns]

# %%
#Mesclar 2 dataframes
gerentes_df = pd.read_excel("Gerentes.xlsx")
#display(gerentes_pd)
vendas_df = vendas_df.merge(gerentes_df)
display(vendas_df)
# Out:
#        Código Venda       Data            ID Loja            Produto  \
# 0             65014 2019-12-01   Shopping Morumbi     Sunga Listrado
# 1             65014 2019-12-01   Shopping Morumbi    Casaco Listrado
# 2             65020 2019-12-01   Shopping Morumbi  Pulseira Listrado
# 3             65020 2019-12-01   Shopping Morumbi    Camiseta Xadrez
# 4             65020 2019-12-01   Shopping Morumbi    Camisa Listrado
# ...             ...        ...                ...                ...
# 14173         69959 2019-12-25  Shopping Eldorado          Polo Liso
# 14174         69959 2019-12-25  Shopping Eldorado       Camisa Linho
# 14175         69959 2019-12-25  Shopping Eldorado       Cueca Xadrez
# 14176         69986 2019-12-26  Shopping Eldorado      Cueca Estampa
# 14177         69986 2019-12-26  Shopping Eldorado     Terno Listrado
#
#        Quantidade  Valor Unitário  Valor Final Gerente
# 0               5             114          570  Gisele
# 1               1             269          269  Gisele
# 2               4              79          316  Gisele
# 3               5             200         1000  Gisele
# 4               2             108          216  Gisele
# ...           ...             ...          ...     ...
# 14173           4             137          548   Paulo
# 14174           3             141          423   Paulo
# 14175           1              60           60   Paulo
# 14176           4              66          264   Paulo
# 14177           3             709         2127   Paulo
#
# [14178 rows x 8 columns]
